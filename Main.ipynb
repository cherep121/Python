# %% [markdown]
# №1) Напишите программу, которая считывает с клавиатуры последовательно три строки:
# название фильма, название кинотеатра и время, после чего выводит на экран «Билет на "
# [название фильма] " в " [название кинотеатра] " на [время] забронирован.».

# %%
film = input()
cinema = input()
time = input()

print("Билет на ", film, " в ", cinema, " на ", time, "забронирован.")

# %% [markdown]
# №2) Напишите программу, которая считывает две строки и выводит «ВЕРНО», если в каждой
# из них записано или слово только да, или только слово нет (в любой комбинации). Если это
# не так, выведите «НЕВЕРНО».

# %%
x = input()
y = input()

if (x == "да" or x == "нет") and (y == "да" or y == "нет"):
    print("ВЕРНО")
else:
    print("НЕВЕРНО")

# %% [markdown]
# №3) Напишите программу, которая проверяет, что пользователь ввёл корректный логин (не
# содержащий символ «@») и корректный резервный адрес (содержащий символ «@»). Иных
# проверок, кроме указанных здесь, выполнять не надо.
# Используйте оператор in.

# %%
login = input()
email = input()

if '@' not in login and '@' in email:
    print("OK")
else:
    print("Некорректный логин или адрес")

# %% [markdown]
# №4) Напишите программу, которая считывает слово (или фразу, неважно) и тут же выводит её,
# и больше ничего не делает.
# Особое условие: необходимо написать эту программу в одну строчку, ограничившись 14
# символами.

# %%
print(input())

# %% [markdown]
# №5) Напишите программу, которая считывает одну строку. Если это пустая строка, т. е. если
# пользователь сразу нажал Enter, то программа выводит «ДА»; в противном случае
# программа выводит «НЕТ».

# %%
x = input()

if x == "":
    print("ДА")
else:
    print("НЕТ")

# %% [markdown]
# №6) Трехзначное число считается красивым, если в нём полусумма максимальной и
# минимальной по значению цифр равна оставшейся цифре числа. Выведите для красивого
# числа фразу "Вы ввели красивое число", а для остальных - "Жаль, вы ввели обычное число".

# %%
print("Ввкдите трехзначное число")
x = int(input())

x1 = x // 100
x2 = (x // 10) % 10
x3 = x % 10
print(x, " - введеное число")


max_x = max(x1, x2, x3)
min_x = min(x1, x2, x3)
print(max_x, " - max цифры из числа")
print(min_x, " - min цифры из числа")

sr = x1 + x2 + x3 - max_x - min_x
print(sr, " - средняя цифра")

if (max_x + min_x) / 2 == sr:
    print("Вы ввели красивое число")
else:
    print("Жаль, вы ввели обычное число")

# %% [markdown]
# №7) Вводится 4-х значное число. Нужно разделить его на отдельные цифры и с их помощью
# записать наименьшее возможное, но тоже четырехзначное число. В задаче нельзя
# использовать циклы, строки и списки.

# %%
num = int(input())

a = num // 1000
b = (num // 100) % 10
c = (num // 10) % 10
d = num % 10

m1 = min(a, b, c, d)
m4 = max(a, b, c, d)

s = a + b + c + d
sum_middle = s - m1 - m4

m2 = m4
if a != m1 and a != m4 and a < m2:
    m2 = a
if b != m1 and b != m4 and b < m2:
    m2 = b
if c != m1 and c != m4 and c < m2:
    m2 = c
if d != m1 and d != m4 and d < m2:
    m2 = d

if m2 == m4:
    m2 = m1

m3 = s - m1 - m2 - m4

if m1 != 0:
    first = m1
    x1, x2, x3 = m2, m3, m4
elif m2 != 0:
    first = m2
    x1, x2, x3 = m1, m3, m4
elif m3 != 0:
    first = m3
    x1, x2, x3 = m1, m2, m4
else:
    first = m4
    x1, x2, x3 = m1, m2, m3

r1 = min(x1, x2, x3)
r3 = max(x1, x2, x3)
r2 = x1 + x2 + x3 - r1 - r3

result = first * 1000 + r1 * 100 + r2 * 10 + r3
print(result)

# %% [markdown]
# №8) Напишите программу, которая считывает рост претендентов в отряд космонавтов до тех
# пор, пока не будет введен «!». А затем выводит на первой строчке количество подходящих
# кандидатур, а на второй строке – минимальный и максимальный рост участников,
# отобранных в новый отряд космонавтов. Рост космонавта не может быть больше 190 см и
# меньше 150 см.

# %%
count = 0
min_height = 150
max_height = 190

while True:
    height = input()
    if height == '!':
        break
    
    height = int(height)
    if 150 <= height <= 190:
        count += 1
        if height <= max_height:
            min_height = height
        if height >= min_height:
            max_height = height

print(count, " - кол-во косманавтов")
print(min_height, " - min рост среди косманавтов", max_height, " - max рост среди косманавтов")

# %% [markdown]
# №9) Напишите программу, которая имитирует проверку пароля, придуманного пользователем.
# Пользователь вводит пару слов: пароль, а потом ещё раз его же, для подтверждения.
# Если введённая пара не удовлетворяет одному из перечисленных ниже условий,
# пользователь вводит пару паролей ещё раз, и так до тех пор, пока не будут выполнены все
# условия (т. е. пока программа не выведет «OK»).
#     если первый пароль из пары, который ввёл пользователь короче 8 символов,
# программа выводит на экран слово "Короткий!" и заново считывает пару словпаролей;
#     если же первый пароль из пары достаточно длинный, но в нём содержится сочетание
# символов "123", программа выводит на экран слово "Простой!" и снова читает пару
# слов-паролей;
#     если же предыдущие проверки пройдены успешно, но введённые слова-пароли не
# совпадают, то программа выводит на экран слово "Различаются." и опять же читает
# пару слов-паролей;
#     если же и третья проверка пройдена успешно, программа выводит "OK" (латинскими
# буквами) и заканчивает свою работу.

# %%
while True:
    password = input()
    confirm = input()
    
    if len(password) < 8:
        print("Короткий!")
        continue
    
    if "123" in password:
        print("Простой!")
        continue
    
    if password != confirm:
        print("Различаются.")
        continue
    
    print("OK")
    break

# %% [markdown]
# №10) Напишите калькулятор для целочисленных вычислений, который обрабатывает серию
# команд и выводит результат вычислений по каждой из них.
# Каждая команда записывается так: сначала вводится первое число, затем символ операции,
# затем — при необходимости — второе число. Символы операций (гарантируется, что
# используются только эти символы):
#     «+» (сложить два числа),
#     «-» (вычесть из первого числа второе),
#     «*» (перемножить два числа),
#     «/» (поделить первое число на второе нацело),
#     «%» (получить остаток от деления первого числа на второе),
#     «!» (посчитать факториал от первого числа, ввод второго числа не производится),
#     «x» (вывести первое число и закончить выполнение программы, ввод второго числа
#     не производится).
# Если пользователь попытается взять факториал от отрицательного числа или сделать ещё
# что-то незаконное, то никакой результат для этой команды выводить не следует.

# %%
while True:
    a = int(input())
    op = input()
    
    if op == 'x':
        print(a)
        break
    
    if op == '!':
        if a < 0:
            continue
        fact = 1
        for i in range(2, a + 1):
            fact *= i
        print(fact)
        continue
    
    b = int(input())
    
    if op == '+':
        print(a + b)
    elif op == '-':
        print(a - b)
    elif op == '*':
        print(a * b)
    elif op == '/':
        if b == 0:
            continue
        print(a // b)
    elif op == '%':
        if b == 0:
            continue
        print(a % b)

# %% [markdown]
# №11) Выведите пирамиду из символов «*» заданной высоты.

# %%
n = int(input())

for i in range(1, n + 1):
    pr = ' ' * (n - i)
    zv = '*' * (2 * i - 1)
    print(pr + zv)

# %% [markdown]
# №12) Напишите программу, принимающую на вход целое положительное число N, и выводящую
# на экран последовательность от 1 до N «ёлочкой».

# %%
n = int(input())

current = 1
row = 1

while current <= n:

    for i in range(row):
        if current <= n:
            print(current, end=' ')
            current += 1
        else:
            break
    print()
    row += 1

# %% [markdown]
# №13) Напишите программу построения прямоугольника n х m, состоящего из символов symb.
# Фигура должна быть пустой, а не заполненной. То есть она должна состоять только из
# контура.

# %%
n = int(input())
m = int(input())
symb = input()

for i in range(n):
    for j in range(m):
        if i == 0 or i == n - 1 or j == 0 or j == m - 1:
            print(symb, end='')
        else:
            print(' ', end='')
    print()
