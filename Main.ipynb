# %% [markdown]
# Задача №1 «Делаем срезы»
# Условие:
# Дана строка.
#     Сначала выведите третий символ этой строки.
#     Во второй строке выведите предпоследний символ этой строки.
#     В третьей строке выведите первые пять символов этой строки.
#     В четвертой строке выведите всю строку, кроме последних двух символов.
#     В пятой строке выведите все символы с четными индексами (считая, что индексация начинается с 0, поэтому символы выводятся начиная с первого).
#     В шестой строке выведите все символы с нечетными индексами, то есть начиная со второго символа строки.
#     В седьмой строке выведите все символы в обратном порядке.
#     В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
#     В девятой строке выведите длину данной строки.

# %%
s = input()
print("начальная строка: ", s)
print("3 символ: ", s[2])
print("2 с конца: ", s[-2])
print("первые 5: ", s[:5])
print("все кроме последних2: ", s[:-2])
print("четные индексы: ", s[::2])
print("нечеитные: ", s[1::2])
print("обратный порядок: ", s[::-1])
print("через один в обратном: ", s[::-2])
print("длина строки: ", len(s))
# Out:
# начальная строка:  qwertyuiop
# 3 символ:  e
# 2 с конца:  o
# первые 5:  qwert
# все кроме последних2:  qwertyui
# четные индексы:  qetuo
# нечеитные:  wryip
# обратный порядок:  poiuytrewq
# через один в обратном:  piyrw
# длина строки:  10

# %% [markdown]
# Задача №2 «Две половинки»
# Условие:
# Дана строка.
#     Разрежьте ее на две равные части (если длина строки — четная, а если длина строки нечетная, то длина первой части должна быть на один символ больше). Переставьте эти две части местами, результат запишите в новую строку и выведите на экран.
#
# При решении этой задачи не стоит пользоваться инструкцией if.

# %%
s = input()
print("начальная строка: ", s)
length = len(s)
ind = (length + 1) // 2

print(s[ind:] + s[:ind])
# Out:
# начальная строка:  qwert
# rtqwe

# %% [markdown]
# Задача №3 «Обращение фрагмента»
# Условие:
#     Дана строка, в которой буква h встречается как минимум два раза. Разверните последовательность символов, заключенную между первым и последним появлением буквы h, в противоположном порядке.

# %%
s = input()
print("начальная строка: ", s)

first_h = s.find('h')
last_h = s.rfind('h')
mid_part = s[first_h + 1:last_h][::-1]
result = s[:first_h + 1] + mid_part + s[last_h:]

print(result)
# Out:
# начальная строка:  qwerhqwehrt
# qwerhewqhrt

# %% [markdown]
# Задача №4 «Первое и последнее вхождения»
# Условие:
# Дана строка.
#     Если в этой строке буква f встречается только один раз, выведите её индекс.
#     Если она встречается два и более раз, выведите индекс её первого и последнего появления.
#     Если буква f в данной строке не встречается, ничего не выводите.
#
# При решении этой задачи не стоит использовать циклы.

# %%
s = input()
print("начальная строка: ", s)
first_f = s.find('f')
last_f = s.rfind('f')

if first_f != -1:
    if first_f == last_f:
        print(first_f)
    else:
        print(first_f, last_f)
# Out:
# начальная строка:  qwefqwef
# 3 7

# %% [markdown]
# Задача №5
# Пользователь (или несколько пользователей за одним компьютером) вводит слова. Начиная
# со второго введённого слова, программа проверяет, совпадает ли первая буква
# свежевведённого слова с последней буквой предыдущего. Если да, то программа работает
# дальше (считывает очередное слово). Если нет — выводит последнее на этот момент
# введённое слово и завершает работу.

# %%
prev_word = input()
print("все введеные слова")
print(prev_word)

while True:
    current_word = input()
    if current_word[0] == prev_word[-1]:
        prev_word = current_word
        print(current_word)
    else:
        print("вывод неподходящего: ", current_word)
        break
# Out:
# все введеные слова
# новгород
# дублин
# новгород
# вывод неподходящего:  москва

# %% [markdown]
# Задача №6
# Выведите слово так, как будто ему что-то мешает произноситься. Каждую букву нужно
# вывести столько раз, каков ее номер в строке.

# %%
s = input()
print("начальная строка: ", s)
result = ''
for i in range(len(s)):
    result += s[i] * (i + 1)

print(result)
# Out:
# начальная строка:  медленее
# меедддллллеееееннннннеееееееееееееее

# %% [markdown]
# Задача №7
# Изобразите извилистый спуск улитки по стене по заданной траектории.
# Вводится одна строка. Начальный символ этой строки — символ рисования пути улитки.
# Далее следует последовательность символов “<”, “>” и “V”, которые означают движение
# улитки, соответственно, влево, вправо и вниз.
# Гарантируется, что по любой горизонтали движение происходит только в одну сторону
# (иными словами, между идущими в любом порядке “<” и “>” всегда есть хотя бы один “V”)
# и что путь не пройдёт левее начального положения.
# Выводятся несколько строк, состоящих из символов рисования пути и пробелов. Верхний
# левый угол соответствует начальному положению улитки. Каждый последующий символ
# входной строки означает, что нужно дорисовать символ рисования пути левее, правее или
# ниже предыдущего. Пробелы используются для отступов.

# %%
path = input().strip()
print(path)
draw_char = path[0]
moves = path[1:]
grid = {}

row = 0
col = 0

grid[(row, col)] = draw_char


min_row = 0
max_row = 0
min_col = 0
max_col = 0

for move in moves:
    if move == '>':
        col += 1
    elif move == '<':
        col -= 1
    elif move == 'V':
        row += 1
    
    min_row = min(min_row, row)
    max_row = max(max_row, row)
    min_col = min(min_col, col)
    max_col = max(max_col, col)
    
    grid[(row, col)] = draw_char

for r in range(min_row, max_row + 1):
    line = []
    for c in range(min_col, max_col + 1):
        if (r, c) in grid:
            line.append(draw_char)
        else:
            line.append(' ')
    print(''.join(line))
# Out:
# #VVVVV>>>>>>^^^>>>>VVV<<<<
# #
# #
# #
# #
# #
# ###########
#           #
#           #
#       #####

# %% [markdown]
# Задача №8
# Давайте попробуем на самом деле растянуть слова, как будто они резиновые. Возьмём за
# середину и будем тянуть. Если в слове нечётное количество букв, на верхушке окажется
# одна буква. А вот если чётное, то тянуть будем за две средние буквы, они и окажутся
# наверху. Напишите программу, которая покажет, как будет выглядеть растянутое слово.
# При решении задачи можно использовать только циклы и операции над строками и
# числами.

# %%
s = input()
print("начальная строка: ", s)
n = len(s)
mid = n // 2

if n % 2 == 1:
    print(' ' * (mid)+s[mid])
    for i in range(1, mid + 1):
        print(' '*(mid-i) + s[mid - i] + ' ' * (2 * i - 1) + s[mid + i])
else:
    print(' ' * (mid - 1) + s[mid - 1] + s[mid])
    for i in range(1, mid):
        print(' '*(mid - 1 - i) + s[mid - 1 - i] + ' ' * (2 * i ) + s[mid + i])
# Out:
# начальная строка:  qwewq
#   e
#  w w
# q   q

# %% [markdown]
# Задача №9 "Больше предыдущего"
# Условие:
#  Дан список чисел.
#     Выведите все элементы списка которые больше предыдущего элемента

# %%
s = list(map(int, input().split()))
print("начальный список: ", s)

for i in range(1, len(s)):
    if s[i] > s[i-1]:
        print(s[i], end=" ")
# Out:
# начальная строка:  [95, 6, 7, 54, 1, 2]
# 7 54 2

# %% [markdown]
# Задача №10 «Соседи одного знака»
# Условие:
#  Дан список чисел.
#     Если в нем есть два соседних элемента одного знака, выведите эти числа. Если соседних элементов одного знака нет - не выводите ничего. Если таких пар соседей несколько - выведите первую пару.

# %%
s = list(map(int, input().split()))
print("начальный список: ", s)

for i in range(1, len(s)):
    if (s[i] > 0 and s[i-1] > 0) or (s[i] < 0 and s[i-1] < 0):
        print(s[i-1], s[i])
        break
# Out:
# начальная строка:  [1, -2, 2, -4, -5]
# -4 -5

# %% [markdown]
# Задача №11 «Переставить соседние»
# Условие:
#     Переставьте соседние элементы списка ( A[0] с A[1] , A[2] с A[3] ит. д.). Если элементов нечетное число, то последний элемент остается на своем месте.

# %%
s = list(map(int, input().split()))
print("начальный список: ", s)
p=0
for i in range(0, len(s) - 1, 2):
    p = s[i]
    s[i] = s[i+1]
    s[i+1] = p


print(*s)
# Out:
# начальная строка:  [1, 2, 3, 4, 5]
# 2 1 4 3 5

# %% [markdown]
# Задача №12 «Уникальные элементы»
# Условие:
# Дан список.
#     Выведите те его элементы, которые встречаются в списке только один раз. Элементы нужно выводить в том порядке, в котором они встречаются в списке.

# %%
s = list(map(int, input().split()))
print("начальный список: ", s)

for i in range(len(s)):
    if s.count(s[i]) == 1:
        print(s[i], end=" ")
# Out:
# начальная строка:  [1, 2, 3, 3, 4, 5, 5]
# 1 2 4

# %% [markdown]
# Задача №13
# Напишите программу, которая составляет новое предложение по номерам слов из исходной
# строки. Предложение должно начинаться с большой буквы. Гарантируется, что в исходной
# строке только одна заглавная буква (в начале предложения).
#     Нумерация слов начинается с единицы.

# %%
num = list(map(int, input().split()))
print("номера слов: ", num)
s = input()
print("предложение: ", s)

words = s.split()

result_parts = []
for idx in num:
    result_parts.append(words[idx-1])

result = ' '.join(result_parts)
print(result)
# Out:
# номера слов:  [3, 2, 1]
# предложение:  я и ты
# ты и я

# %% [markdown]
# Задача №14 «Ферзи»
# Условие:
#     Известно, что на доске 8×8 можно расставить 8 ферзей так, чтобы они не били друг друга. Вам дана расстановка 8 ферзей на доске, определите, есть ли среди них пара бьющих друг друга. Программа получает на вход восемы пар чисел. каждое число от 1 до 8 - координаты 8 ферзей. Если ферзи не бьют друг друга, выведите слово No , иначе выведите YES .

# %%
queens = []
for i in range(8):
    x, y = map(int, input().split())
    queens.append((x, y))

print("Введенные позиции ферзей:")
for i, (x, y) in enumerate(queens, 1):
    print("Ферзь", i, " на (", x, y,")")


attacking = False

for i in range(8):
    for j in range(i + 1, 8):
        x1, y1 = queens[i]
        x2, y2 = queens[j]
        
        if y1 == y2:
            attacking = True
            break
            
        if x1 == x2:
            attacking = True
            break
            
        if abs(x1 - x2) == abs(y1 - y2):
            attacking = True
            break
    
    if attacking:
        break

print("\nРезультат проверки:")
if attacking:
    print("YES - ферзи бьют друг друга")
else:
    print("NO - ферзи не бьют друг друга")
# Out:
# Введенные позиции ферзей:
# Ферзь 1  на ( 1 1 )
# Ферзь 2  на ( 2 3 )
# Ферзь 3  на ( 3 5 )
# Ферзь 4  на ( 4 7 )
# Ферзь 5  на ( 5 2 )
# Ферзь 6  на ( 6 4 )
# Ферзь 7  на ( 7 6 )
# Ферзь 8  на ( 8 8 )
#
# Результат проверки:
# YES - ферзи бьют друг друга

# %% [markdown]
# Задача №15
# Окунёмся в суровый и беспощадный мир очереди на приём к врачу в поликлинике. Напишите программу-медсестру, которая поможет врачу определить, кто следующий проходит к нему в кабинет. Изначально в очереди никого нет. Далее в каком-то порядке происходят события трёх типов:
#
#     фраза «Кто последний? Я - <фамилия>.» означает, что пришёл новый пациент и встал в конец очереди;
#     фраза «Я только спросить! Я - <фамилия>.» означает, что пришёл новый пациент и встал в начало очереди;
#     фраза «Следующий!» означает, что доктор готов принять первого пациента в очереди. В последнем случае нужно вывести «Заходит <фамилия>!» или «В  очереди никого нет.» На психологическую достоверность данная модель очереди, конечно, не претендует: в жизни такое нахальство с «я только спросить» прощается далеко не всегда

# %%
n = int(input())
queue = []

for i in range(n):
    event = input().strip()
    
    if event.startswith("Кто последний?"):
        name = event.split(" - ")[1].rstrip(".")
        queue.append(name)
    
    elif event.startswith("Я только спросить!"):
        name = event.split(" - ")[1].rstrip(".")
        queue.insert(0, name)
    
    elif event == "Следующий!":
        if queue:
            patient = queue.pop(0)
            print("Заходит", patient, "!")
        else:
            print("В очереди никого нет.")

    elif event == "Следующий":
        if queue:
            patient = queue.pop(0)
            print("Заходит", patient, "!")
        else:
            print("В очереди никого нет.")
# Out:
# Заходит Кузнецов !
# Заходит Иванов !
# Заходит Поливанов !
# В очереди никого нет.
